# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Andrew Henry**
#
# Student

# %% [markdown]
# *I am interested in data science because I enjoy gathering and analyzing data to solve problems.*

# %% [markdown]
# ### The code in cell 5 is to add the numbers 6 and 4 together.

# %%
6+4
# Out:
# 10

# %% [markdown]
# | 6+4 equals | 6+4 does NOT equal |
# |------|------|
# | 10 | 3 |
# |   | 7 |
# |   | 24 |
#
# 6 plus 4 equals
# 1. 10
# 2. ~~24~~
#
# > Herein, I have concluded that 6 plus 4 equals 10
